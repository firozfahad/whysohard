# %% [markdown]
# Two level sort

# %%
def two_level_sort(scores):
    sorted=[]
    while scores:
        min_entry=scores[0]
        for i in scores:
            if i[1]<min_entry[1] or (i[1]==min_entry[1] and i[0]<min_entry[0]):
                min_entry=i
        sorted.append(min_entry)
        scores.remove(min_entry)
    return sorted

# %% [markdown]
# Write a function named get_range that accepts a list of real numbers as argument. It should return the range of the list.

# %%
min=max=None
def get_range(L):
    if not L:
        return None
    min_n=float(L[0])
    max_n=float(L[0])
    for i in L: # s in L
        if i<min_n:
            min_n=i
        if i>max_n:
            max_n=i
    return float(max_n-min_n)

# %% [markdown]
# Write a function named is_perfect that accepts a positive integer
#
# n as argument and returns True if it is perfect, and False otherwise

# %%
def is_perfect(n):
    f=0
    for i in range(1,n): #(1,n)
        if n%i==0:
            f=f+i
    return f==n


print(is_perfect(int(input())))

# %% [markdown]
# Transpose

# %%
def transpose_matrix(matrix):
    return [[matrix[j][i] for j in range(len(matrix))] for i in range(len(matrix[0]))] # reverses rows and columns

print(transpose_matrix([[1,2,3],[4,5,6],[7,8,9]]))
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
def transpose(mat):
    n=len(mat)
    m=len(mat[0])
    return[[mat[j][i] for j in range(n)] for i in range(m)]

print(transpose([[1,2,3],[4,5,6],[7,8,9]]))
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
def get_col(mat,j):
    col=[]
    n=len(mat)
    
    for i in range(n):
        col.append(mat[i][j])
    return col

def transpose(mat):
    trans=[]
    m=len(mat[0])
    for i in range(m):
        trans.append(get_col(mat,i))
    return trans
        
    
print(transpose([[1,2,3],[4,5,6],[7,8,9]])) #(1,2,3)
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
def get_col(mat,col):
    col_list=[]
    m=len(mat)
    for row in range(m):
        col_list.append(mat[row][col])
    return col_list
 
def transpose(mat):
    m,n=len(mat),len(mat[0])
    trans=[]
    for i in range(n):
        trans.append(get_col(mat,i))
    return trans

print(transpose([[1],[4,5,6],[7,8,9]]))
# Out:
# [[1, 4, 7]]

# %%
def add_ones(M):
    for i in range(len(M)):
        M[i].insert(0,1)
   
    return M
print(add_ones([[1,2],[3,4]]))
# Out:
# [[1, 1, 2], [1, 3, 4]]

# %%
def add_ones(M):
    n=len(M)

# %% [markdown]
# > vote

# %%
def outcome(results):
    max=0
    for i in results:
        if results[i]>max:
            max=results[i]
            name=i
    return name
    
print(outcome({'a':10,'b':20,'c':30}))
# Out:
# c

# %% [markdown]
# **orthiogonal vec**

# %%
def orthogonal(L,v):
    dot=0
    for i in range(len(v)):
        dot=dot+L[i]*v[i]
    return dot
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       1 def orthogonal(L,v):
#       2     return [sum(i*j for i,j in zip(L,v)) for v in L]
# ----> 4 print(orthogonal([[1,2],[3,4]],[5,6]))
#
# Cell In[25], line 2, in orthogonal(L, v)
#       1 def orthogonal(L,v):
# ----> 2     return [sum(i*j for i,j in zip(L,v)) for v in L]
#
# Cell In[25], line 2, in <listcomp>(.0)
#       1 def orthogonal(L,v):
# ----> 2     return [sum(i*j for i,j in zip(L,v)) for v in L]
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %% [markdown]
# > rotate list

# %%
def rotate_list(lst, k):
    n = len(lst)
    k = k % n  # Ensure k is within the length of the list

    rotated_list = lst[-k:] + lst[:-k]
    return rotated_list

# Input processing
input_sequence = input()
input_k = int(input())

# Convert input sequence to a list of integers
sequence = [int(x) for x in input_sequence.split(',')]

# Perform k rotations and print the result
result = rotate_list(sequence, input_k)
print(','.join(map(str, result)))

# %%
def rotate(L,k):
    n=len(L)
    k=k%n
    rotated=list[-k:]+list[:-k]
    return rotated
print(rotate([1,2,3,4,5],3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 6
#       4     rotated=list[-k:]+list[:-k]
#       5     return rotated
# ----> 6 print(rotate([1,2,3,4,5],3))
#
# Cell In[27], line 4, in rotate(L, k)
#       2 n=len(L)
#       3 k=k%n
# ----> 4 rotated=list[-k:]+list[:-k]
#       5 return rotated
#
# TypeError: unsupported operand type(s) for +: 'types.GenericAlias' and 'types.GenericAlias'

# %% [markdown]
# > **You have
# > n gold coins with you. You wish to divide this among three of your friends under the following conditions:
# > * (1) All three of them should get a non-zero share.
# > * (2) No two of them should get the same number of coins.
# > * (3) You should not have any coins with you at the end of this sharing process.
# > The input has four lines. The first line contains the number of coins with you. The next three lines will have the share given to your three friends. All inputs shall be non-negative integers. If the division satisfies these conditions, then print the string FAIR. If not, print UNFAIR.**

# %%
#not even a function '
#just get input n return true false

n=int(input())
f1,f2,f3=int(input()),int(input()),int(input())

c=False # since trree cond
if f1!=0 andf2!=0 and f3!=0:
    c=True
if f1!=f2 and f2!=f3 and f3!=f1:
    c=True
if n-f1-f2-f3=0:
    c=True
if c:
    print('Fair')
else:
    print('Unfair')
'
# Out:
#   Cell In[3], line 18
#     '
#     ^
# SyntaxError: unterminated string literal (detected at line 18)

# %% [markdown]
# Write a function create that accepts a positive integer
# �
# n as argument and returns a list of the first
# �
# n positive integers using list comprehension. Appending to a list within a for-loop will not fetch you marks even if it passes the test cases

# %%
def create(n):
    return [x for x in range(1, n + 1)]

# %% [markdown]
#  Write a function named insert that accepts a sorted list L of integers and an integer x as arguments. It should return a sorted list with the element x inserted into the input list at the right place.
#
# (2) Write a recursive function named isort that accepts a non-empty list L of integers as argument. It should return a sorted list in ascending order. isort must make use of insert. This is a popular sorting algorithm and is called insertion sort.

# %%
def insert(L, x):
    out_L = [ ]
    inserted = False
    for elem in L:
        if not inserted and x < elem:
            out_L.append(x)
            inserted = True
        out_L.append(elem)
    if not inserted:
        out_L.append(x)
    return out_L

def isort(L):
    if len(L) == 1:
        return L
    return insert(isort(L[: -1]), L[-1])

# %% [markdown]
# The scores dataset is a list of dictionaries one of whose entries is given below for your reference:
#
# {'SeqNo': 0, 'Name': 'Devika', 'Gender': 'F', 'City': 'Bengaluru',
#  'Mathematics': 85, 'Physics': 100, 'Chemistry': 79}
# Write a function named collection_to_file that accepts the scores_dataset as argument. Within the function, create a CSV file named scores.csv with the following header:
#
# SeqNo,Name,Gender,City,Mathematics,Physics,Chemistry
# Each line in the file after the header should have the details of one student. The file should be arranged in increasing order of SeqNo. To simplify things, scores_dataset is already sorted in the increasing order of SeqNo.

# %%
def collection_to_file(scores_dataset):
    f = open('scores.csv', 'w')
    f.write('SeqNo,Name,Gender,City,Mathematics,Physics,Chemistry\n') 
    for stud in scores_dataset:
        sno = stud['SeqNo']
        name = stud['Name']
        gender = stud['Gender']
        city = stud['City']
        ma = stud['Mathematics']
        phy = stud['Physics']
        chm = stud['Chemistry']
        line = f'{sno},{name},{gender},{city},{ma},{phy},{chm}\n'
        if stud['SeqNo'] == scores_dataset[-1]['SeqNo']:
            line = line.strip()
        f.write(line)
    f.close()

# %%
def hostile(x, y):
    return set(str(x)).intersection(set(str(y))) == set()

# %%
results=[]
for i in range(8):
    L=input().split(',')
    winner=L[0]
    losers=L[1:]
    results.append((winner,len(losers)))

sorted_list=sorted(results,key=lambda x: (-x[1],x[0]))
for team,wins in sorted_list:
    print(f'{team}:{wins}')

# %% [markdown]
# # ****sorted list****

# %%
def soln(L):
    for i in range(len(L)):
        for j in  range(i+1,len(L)):
            if L[i]>L[j]:
                L[i],L[j]=L[j],L[i]
    return L


print(soln([1,2,3,4,5,6,7,8,9]))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def insert(L,x):
    # easy wayy is random append tht x the care abt sorty
    L.append(x)
    for i in range(len(L)):
        for j in range(i+1,len(L)):
            if L[i]>L[j]:
                L[i],L[j]=L[j],L[i]
    return L
                
L=[2,3,4,6]
x=6.00001
print(insert(L,x))
# Out:
# [2, 3, 4, 6, 6.00001]

# %%
def insert(L,x):
    for i in range(len(L)):
        if x>L[i] and x<L[i+1]:
            L[i+0.5]=x
    return L

print(insert([2,3,4],1.5))
# Out:
# [2, 3, 4]

# %% [markdown]
# # Matrix

# %% [markdown]
# > * transpose
# > *get col
# > *get row
# >rotate list
# >rotate 90*
# >

# %%
def get_column(mat, col):
    l=[]
    for i in range(len(mat)):
        l.append(mat[i][col]) #individual element
    return l

mat=[[1,2,3],[4,5,6],[7,8,9]]
print(get_column(mat,1))
# Out:
# [2, 5, 8]

# %%
def get_col(A):
    col_list=[]
    for i in range(len(A)):
        col_list.append(A[i][j])
    return col_list
A=[[1,2,3],[4,5,6],[7,8,9]]                   
print(get_col(A),)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def get_column(mat, col):
    l=[]
    for i in range(len(mat)):
        l.append(mat[i][col]) #individual element
    print(l)


'''def get_row(mat,row):
    row_l=[]
    for i in range(len(mat)):
        row_l.append(mat[row][i])
    return row_l'''




def transpose(mat):
    m,n=len(mat),len(mat[0])
    trans=[]
    for i in range(n):
        trans.append(get_col(mat,i))
    return trans

        
mat=[[1,2,3],[4,5,6],[7,8,9]]
print(get_column(mat,1))
print(get_row(mat,2))

print(transpose(mat))
# Out:
# [2, 5, 8]
# None
# [7, 8, 9]
# [[1, 1, 1, 4, 4, 4, 7, 7, 7], [2, 2, 2, 5, 5, 5, 8, 8, 8], [3, 3, 3, 6, 6, 6, 9, 9, 9]]

# %%
def get_row:

# %% [markdown]
# (1) factors: accept a positive integer
# �
# n as argument. Return the set of all factors of
# �
# n.
#
# (2) common_factors: accept two positive integers
# �
# a and
# �
# b as arguments. Return the set of common factors of the two numbers. This function must make use of factors.
#
# (3) factors_upto: accept a positive integer
# �
# n as argument. Return a dict D, whose keys are integers and values are sets. Each integer in the range
# [
# 1
# ,
# �
# ]
# [1,n], endpoints inclusive, is a key of D. The value corresponding to a key, is the set of all factors of key. This function must make use of factors.
#
# The idea we are trying to bring out here is to make use of pre-defined functions whenever needed.

# %%
def swap_case(s):
    s = list(s)
    for i in range(len(s)):
        if s[i].islower():
            s[i] = s[i].upper()
        elif s[i].isupper():
            s[i] = s[i].lower()
            
    return ''.join(s)

if __name__ == '__main__':
    s = input()
    result = swap_case(s)
    print(result)
# Out:
#  DghfyyguihTTGYHUHUGyghuj
# dGHFYYGUIHttgyhuhugYGHUJ

# %%
def get_col(mat,col):
    col_list=[]
    for i in range(len(mat)):
        col_list.append(mat[i][col])
    return col_list

def transpose(mat):
    trans=[]
    for i in range(len(mat[0])):
        trans.append(get_col(mat,i))
    return trans


def add_ones(mat):
    for i in range(len(mat[0])):
        mat[i].insert(0,1)
    return mat


mat=[[1,2,3],[4,5,6],[7,8,9]]
print(transpose(mat))
print(add_ones(mat))
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]
# [[1, 1, 2, 3], [1, 4, 5, 6], [1, 7, 8, 9]]

# %%
def group_by_city(scores_dataset):
